# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.random((10, 1))
print(x)
# Out:
# [[0.58685061]
#  [0.99092989]
#  [0.29735105]
#  [0.76389714]
#  [0.41426505]
#  [0.96078859]
#  [0.56079954]
#  [0.96078314]
#  [0.78131208]
#  [0.08381984]]

# %%
plt.plot(x, '*-')
plt.show()
